# %%
import urllib2
import urllib
from bs4 import BeautifulSoup
import sys
import requests
import json
import time
import re
import csv
import re
import time
import pandas as pd
import numpy as np
from pandas import ExcelWriter

# %%
def post_(url,params1):
	r = requests.post(url,params=params1)
	return r
def get_(url,params1):
	r = requests.get(url,params=params1)
	return r
def get_nop(url,params1):
	r = requests.get(url)
	return r
def get_prod_details(url):
	html = get_nop(url,{})
	soup = BeautifulSoup(html.text,"html.parser")
	#title-wrap line fk-font-family-museo section omniture-field
	prod ={}
	name = soup.findAll("div", { "class" : "title-wrap line fk-font-family-museo section omniture-field" })
	prod['name']=name[0].text.strip()
	#keyFeatures specSection
	description = soup.findAll("div", { "class" : "gd-col gu12"})
	text = ''
	for d in description:
		text = text + get_text(d).strip()
	prod['description'] = my_strip(text)
	#key-specifications fk-ul-disc lpadding20 line fk-font-11 fk-fontlight
	description2 = soup.findAll("ul", { "class" : "key-specifications fk-ul-disc lpadding20 line fk-font-11 fk-fontlight" })
	text = ''
	for d in description2:
		text = text + get_text(d)
	prod['description2'] = my_strip(text)
	return prod
def parse_prod(prod):
	#print prod
	#fk-display-block
	title = prod.findAll("a", { "class" : "fk-display-block" },href=True)
	p={}
	p['url'] = base_url + title[0]['href']
	return p 
	
def get_text(node):
	#print node
	addinfo = node
	if len(addinfo) > 0:
			addinfo = ''.join(addinfo.findAll(text=True))
	else:
		addinfo = ''
	return addinfo
def my_strip(text):
	text = re.sub('\s+',' ',text)
	return text

# %%
for i in range(0,1):
    api_url = 'https://en.wikipedia.org/wiki/List_of_government_schemes_in_India';
    params = {
    'sid':"mgl,u35",
    'filterNone':True,
    'start':1,
    'ajax':True,
    '_':1453012261736
    };
for i in range(1,2):
    p = params
    p['start'] = i
    html = get_(api_url,p)

# %%
def getSalary(queryState, queryTitle):    
    base_url = 'http://www.indeed.com/jobs?q='
    end_url = '&l=';
    final_url = base_url+queryTitle+end_url+queryState;
    #print final_url;
    for i in range(0,1):
        api_url = final_url;
        params = {
        'sid':"mgl,u35",
        'filterNone':True,
        'start':1,
        'ajax':True,
        '_':1453012261736
        };
    for i in range(1,2):
        p = params
        p['start'] = i
        html = get_(api_url,p)
        #print html.text
        soup = BeautifulSoup(html.text,"html.parser")
        sa = soup.findAll("div", { "id" : "SALARY_rbo" },href=False)
        Salary = sa[0].text.strip();
        Salary = Salary.replace("\n\n",", ");
        co = soup.findAll("div", { "id" : "searchCount" },href=False);
        count = co[0].text.strip();
        count = count.split('of')[1];
        count = count.strip();
    return Salary, count;

# %%
queries = pd.read_csv('remCntQuery.csv');
result_salary = [];
result_count = [];
queries.shape
# Out:
# (164, 2)

# %%
cnt = 0;
for i in range(0,queries.shape[0]):
    print "Per Complete->"+str(i*100.0/queries.shape[0]);
    queryState = queries['state'][i];
    queryTitle = queries['query-with title'][i];
    try:
        Salary,Count = getSalary(queryState, queryTitle);
    except Exception, e:
        Salary = e;
        Count = 0;
    result_salary.append(Salary)
    result_count.append(Count)
    cnt = cnt+1;
    if(cnt==1000):
        cnt = 0;
        df = pd.DataFrame(result_salary);
        df.to_csv('salaryDump'+str(i)+'.csv');
        df = pd.DataFrame(result_count);
        df.to_csv('countDump'+str(i)+'.csv');
df = pd.DataFrame(result_salary);
df.to_csv('salaryDump-Final.csv');
df = pd.DataFrame(result_count);
df.to_csv('countDump-Final.csv');
# Out:
# Per Complete->0.0
# Per Complete->0.00612745098039
# Per Complete->0.0122549019608
# Per Complete->0.0183823529412
# Per Complete->0.0245098039216
# Per Complete->0.030637254902
# Per Complete->0.0367647058824
# Per Complete->0.0428921568627
# Per Complete->0.0490196078431
# Per Complete->0.0551470588235
# Per Complete->0.0612745098039
# Per Complete->0.0674019607843
# Per Complete->0.0735294117647
# Per Complete->0.0796568627451
# Per Complete->0.0857843137255
# Per Complete->0.0919117647059
# Per Complete->0.0980392156863
# Per Complete->0.104166666667
# Per Complete->0.110294117647
# Per Complete->0.116421568627
# Per Complete->0.122549019608
# Per Complete->0.128676470588
# Per Complete->0.134803921569
# Per Complete->0.140931372549
# Per Complete->0.147058823529
# Per Complete->0.15318627451
# Per Complete->0.15931372549
# Per Complete->0.165441176471
# Per Complete->0.171568627451
# Per Complete->0.177696078431
# Per Complete->0.183823529412
# Per Complete->0.189950980392
# ...

# %%
df = pd.DataFrame(result_salary);
df.to_csv('salaryDump-Final_1.csv');
df = pd.DataFrame(result_count);
df.to_csv('countDump-Final_2.csv');

# %%
cnt = 0;
for i in range(0,queries.shape[0]):
    print "Per Complete->"+str(i*100.0/queries.shape[0]);
    queryState = queries['state'][i];
    queryTitle = queries['query-with title'][i];
    try:
        Salary,Count = getSalary(queryState, queryTitle);
    except Exception, e:
        Salary = e;
        Count = 0;
    result_salary.append(Salary)
    result_count.append(Count)
    cnt = cnt+1;
    if(cnt==1000):
        cnt = 0;
        df = pd.DataFrame(result_salary);
        df.to_csv('salaryDump'+str(i)+'.csv');
        df = pd.DataFrame(result_count);
        df.to_csv('countDump'+str(i)+'.csv');
df = pd.DataFrame(result_salary);
df.to_csv('salaryDumpRem-Final.csv');
df = pd.DataFrame(result_count);
df.to_csv('countDumpRem-Final.csv');
# Out:
# Per Complete->0.0
# Per Complete->0.609756097561
# Per Complete->1.21951219512
# Per Complete->1.82926829268
# Per Complete->2.43902439024
# Per Complete->3.0487804878
# Per Complete->3.65853658537
# Per Complete->4.26829268293
# Per Complete->4.87804878049
# Per Complete->5.48780487805
# Per Complete->6.09756097561
# Per Complete->6.70731707317
# Per Complete->7.31707317073
# Per Complete->7.92682926829
# Per Complete->8.53658536585
# Per Complete->9.14634146341
# Per Complete->9.75609756098
# Per Complete->10.3658536585
# Per Complete->10.9756097561
# Per Complete->11.5853658537
# Per Complete->12.1951219512
# Per Complete->12.8048780488
# Per Complete->13.4146341463
# Per Complete->14.0243902439
# Per Complete->14.6341463415
# Per Complete->15.243902439
# Per Complete->15.8536585366
# Per Complete->16.4634146341
# Per Complete->17.0731707317
# Per Complete->17.6829268293
# Per Complete->18.2926829268
# Per Complete->18.9024390244
# Per Complete->19.512195122
# ...

# %%
def test_query(ind):
    queryState = queries['state'][ind];
    queryTitle = queries['query-with title'][ind];
    try:
        Salary = getSalary(queryState, queryTitle);
    except Exception, e:
        Salary = '';
    print Salary;

# %%
test_query(2922)
# Out:
# http://www.indeed.com/jobs?q=(medical  or  biotech  or  clinical  or  biotechnology  )      title:(lab  or  laboratory    -scientist  -researcher  -supervisor)&l=New  Mexico
# $25,000+ (115), $30,000+ (75), $35,000+ (65), $50,000+ (45), $65,000+ (27)

# %%
queryState = queries['state'][0];
queryTitle = queries['query-with title'][0];
base_url = 'http://www.indeed.com/jobs?q='
end_url = '&l=';
final_url = base_url+queryTitle+end_url+queryState;
print final_url;
for i in range(0,1):
    api_url = final_url;
    params = {
    'sid':"mgl,u35",
    'filterNone':True,
    'start':1,
    'ajax':True,
    '_':1453012261736
    };
for i in range(1,2):
    p = params
    p['start'] = i
    html = get_(api_url,p)
    #print html.text
    soup = BeautifulSoup(html.text,"html.parser")
    sa = soup.findAll("div", { "id" : "SALARY_rbo" },href=False)
    Salary = sa[0].text.strip();
    Salary = Salary.replace("\n\n",", ");
    co = soup.findAll("div", { "id" : "searchCount" },href=False);
    count = co[0].text.strip();
    count = count.split('of')[1];
    count = count.strip();
print soup
